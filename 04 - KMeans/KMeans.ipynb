# %% [markdown]
# * Entrada: Lista de puntos y K
# * Elegir K puntos al azar como centroides
# * Repetir hasta que los centroides no se muevan
# * Para cada punto de la lista calcular la distancia con los k centroides
# * Asignar el punto al centroides más cercano
# * Calcular el centro medio de cada grupo
# * El nuevo centroide será el centro medio calculado

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

puntos, etiquetas_reales = make_blobs(n_samples = 300, centers = 4, cluster_std = 0.60, random_state = 0)

kmeans = KMeans(n_clusters = 4, init='random', n_init=10, max_iter=300, random_state=42)

kmeans.fit(puntos)

grupos_estimados = kmeans.predict(puntos)

centroides = kmeans.cluster_centers_

# %%
plt.figure(figsize=(10,8))
plt.scatter(puntos[:, 0], puntos[:, 1], c = grupos_estimados, cmap = "viridis", label = "Puntos", alpha = 0.6)
plt.scatter(centroides[:, 0], centroides[:, 1], color = "red", marker = "*", label = "Centroides")
plt.legend()
plt.show()
